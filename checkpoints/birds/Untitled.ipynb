# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('trainloss.txt', 'r') as trainfile:
    train_losses =trainfile.read()
trainloss = []
for t in train_losses.split(','):
               trainloss.append(float(t))
plt.figure(figsize=(12,6))
plt.plot(trainloss)

# %%
with open('testloss.txt', 'r') as testfile:
    test_losses =testfile.read()
testloss = []
for t in test_losses.split(','):
               testloss.append(float(t))
plt.figure(figsize=(12,6))
plt.plot(testloss)

# %%
testloss
# Out:
# [13.063056945800781,
#  13.082079887390137,
#  19.08246612548828,
#  24.932397842407227,
#  23.15393829345703,
#  26.295879364013672,
#  20.00401496887207,
#  20.14754295349121,
#  26.239591598510742,
#  14.586285591125488,
#  19.218067169189453,
#  14.519354820251465,
#  12.483973503112793,
#  18.115772247314453,
#  35.22569274902344,
#  16.151185989379883,
#  21.640165328979492,
#  15.54467487335205,
#  14.739275932312012,
#  14.80420970916748,
#  16.16950225830078,
#  27.494626998901367,
#  24.693771362304688,
#  17.427310943603516,
#  26.231576919555664,
#  16.971925735473633,
#  17.01220703125,
#  14.934576034545898,
#  21.86086082458496,
#  22.430482864379883,
#  18.972000122070312,
#  17.57649803161621,
#  13.116166114807129,
#  19.992666244506836,
#  20.144271850585938,
#  22.26007652282715,
#  15.495157241821289,
#  16.73012924194336,
#  26.109237670898438,
#  13.516315460205078,
#  16.711505889892578,
#  19.069900512695312,
#  15.773890495300293,
#  23.936111450195312,
# ...

# %%
# Out:
# 13.063056945800781

# %%
# Out:
# str

# %%
# Out:
# 0
